# %%
import numpy as np
import matplotlib.pyplot as plt
import Isotropy_measure as IM

# %%
cluster1 = np.random.normal(loc=[-3, 0], scale=[1, 1], size=(100, 2))
cluster2 = np.random.normal(loc=[3, 0], scale=[1, 4], size=(100, 2))

# %%
# Scatter plot of the two clusters
plt.scatter(cluster1[:, 0], cluster1[:, 1], label='Cluster 1')
plt.scatter(cluster2[:, 0], cluster2[:, 1], label='Cluster 2')

# Add legend, axis labels and title
plt.legend()
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Two 2D Clusters')
#Square the axis to demonstrate the isotropy
plt.xlim([-10,10])
plt.ylim([-10,10])
# Show the plot
plt.show()

# %%
print("Cluster 1:")
print("Fractional anisotropy:", IM.fractional_anisotropy(cluster1))
print("Var lambda:", IM.var_lambda(cluster1))
print("I_rnd:", IM.i_rnd(cluster1))
print("I_vec:", IM.i_vec(cluster1))
print("Isotropy", isotropy(cluster1,mode='unit_sample'))
# Out:
# Cluster 1:
# Fractional anisotropy: 0.10673333274471895
# Var lambda: 0.002880819386592453
# I_rnd: 0.9982717380912189
# I_vec: 0.9230055540295555
# Isotropy 0.9945484689406198

# %%
print("Cluster 2:")
print("Fractional anisotropy:", IM.fractional_anisotropy(cluster2))
print("Var lambda:", IM.var_lambda(cluster2))
print("I_rnd:", IM.i_rnd(cluster2))
print("I_vec:", IM.i_vec(cluster2))
print("Isotropy", isotropy(cluster2,mode='unit_sample'))
# Out:
# Cluster 2:
# Fractional anisotropy: 0.6689655307710778
# Var lambda: 0.20250087570742936
# I_rnd: 0.9980289282632877
# I_vec: 0.5095045685104761
# Isotropy 0.994421697254333

# %%
both_clusters = np.concatenate([cluster1, cluster2])
labels = [0]*cluster1.shape[0] + [1]*cluster2.shape[0]

# %%
print("Global results (both clusters):")
print("Fractional anisotropy:", IM.fractional_anisotropy(bot))
print("Var lambda:", IM.var_lambda(cluster2))
print("I_rnd:", IM.i_rnd(cluster2))
print("I_vec:", IM.i_vec(cluster2))
print("Isotropy", isotropy(cluster2,mode='unit_sample'))
# Out:
# (200, 2)
